# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhaK/ICT-academy/blob/main/linearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-277180c5-2cc4-40e9-adb5-996f81d3d43a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-277180c5-2cc4-40e9-adb5-996f81d3d43a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('cardekho.csv', index_col=0)
data.head(10)
# Out:
#                                       year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI                2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition          2014         370000     120000  Diesel
# Honda City 2017-2020 EXi              2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel             2010         225000     127000  Diesel
# Maruti Swift VXI BSIII                2007         130000     120000  Petrol
# Hyundai Xcent 1.2 VTVT E Plus         2017         440000      45000  Petrol
# Maruti Wagon R LXI DUO BSIII          2007          96000     175000     LPG
# Maruti 800 DX BSII                    2001          45000       5000  Petrol
# Toyota Etios VXD                      2011         350000      90000  Diesel
# Ford Figo Diesel Celebration Edition  2013         200000     169000  Diesel
#
#                                      seller_type transmission         owner  \
# name
# ...

# %%
data.tail()
# Out:
#                         year  selling_price  km_driven    fuel seller_type  \
# name
# Hyundai i20 Magna       2013         320000     110000  Petrol  Individual
# Hyundai Verna CRDi SX   2007         135000     119000  Diesel  Individual
# Maruti Swift Dzire ZDi  2009         382000     120000  Diesel  Individual
# Tata Indigo CR4         2013         290000      25000  Diesel  Individual
# Tata Indigo CR4         2013         290000      25000  Diesel  Individual
#
#                        transmission                 owner  mileage(km/ltr/kg)  \
# name
# Hyundai i20 Magna            Manual           First Owner               18.50
# Hyundai Verna CRDi SX        Manual  Fourth & Above Owner               16.80
# Maruti Swift Dzire ZDi       Manual           First Owner               19.30
# Tata Indigo CR4              Manual           First Owner               23.57
# Tata Indigo CR4              Manual           First Owner               23.57
#
# ...

# %%
data.shape
# Out:
# (8128, 11)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.plot(kind='scatter',x='selling_price',y='year',color='red')
data.plot(kind='scatter',x='km_driven',y='year',color='blue')
# Out:
# <Axes: xlabel='km_driven', ylabel='year'>

# %%
feature_cols = ['selling_price', 'km_driven']
X = data[feature_cols]
X.head()
# Out:
#                               selling_price  km_driven
# name
# Maruti Swift Dzire VDI               450000     145500
# Skoda Rapid 1.5 TDI Ambition         370000     120000
# Honda City 2017-2020 EXi             158000     140000
# Hyundai i20 Sportz Diesel            225000     127000
# Maruti Swift VXI BSIII               130000     120000

# %%
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (8128, 2)

# %%
lab = ['year']

# %%
y =  data['year']
y.head()
# Out:
# name
# Maruti Swift Dzire VDI          2014
# Skoda Rapid 1.5 TDI Ambition    2014
# Honda City 2017-2020 EXi        2006
# Hyundai i20 Sportz Diesel       2010
# Maruti Swift VXI BSIII          2007
# Name: year, dtype: int64

# %%
print(type(y))
print(y.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (8128,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (6096, 2)
# (6096,)
# (2032, 2)
# (2032,)

# %%
print(X_test)
# Out:
#                                         selling_price  km_driven
# name
# Mahindra Bolero DI AC BSIII                    250000      80000
# Tata Hexa XT                                  1282000      45000
# Hyundai Elite i20 Diesel Sportz                700000      60000
# Tata Tiago 2019-2020 XZ                        500000      15000
# Maruti Eeco 7 Seater Standard BSIV             270000     100000
# ...                                               ...        ...
# Audi A6 2.0 TDI Technology                    1750000      33900
# MG Hector Sharp DCT Dualtone                  1900000       1600
# Honda Civic ZX Diesel BSIV                    2125000       5500
# Toyota Innova Crysta 2.4 GX MT 8S BSIV        1490000      56900
# Tata Hexa XT                                  1525000      50000
#
# [2032 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()
model = linreg.fit(X_train, y_train)

# %%
y_pred = linreg.predict(X_test)
print(y_pred)
# Out:
# [2012.89096606 2015.54321531 2014.18778666 ... 2018.0328053  2015.51648797
#  2015.77561586]

# %%
print(X_test)
# Out:
#                                         selling_price  km_driven
# name
# Mahindra Bolero DI AC BSIII                    250000      80000
# Tata Hexa XT                                  1282000      45000
# Hyundai Elite i20 Diesel Sportz                700000      60000
# Tata Tiago 2019-2020 XZ                        500000      15000
# Maruti Eeco 7 Seater Standard BSIV             270000     100000
# ...                                               ...        ...
# Audi A6 2.0 TDI Technology                    1750000      33900
# MG Hector Sharp DCT Dualtone                  1900000       1600
# Honda Civic ZX Diesel BSIV                    2125000       5500
# Toyota Innova Crysta 2.4 GX MT 8S BSIV        1490000      56900
# Tata Hexa XT                                  1525000      50000
#
# [2032 rows x 2 columns]
